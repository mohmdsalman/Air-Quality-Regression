# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Problem statement**
#
# - **The Air Quality Index (AQI) is used for reporting daily air quality. It tells you how clean or polluted your air is.The dataset contains air quality data and AQI (Air Quality Index)at hourly and daily level of various stations across multiple cities in India.**

# %%
data = pd.read_csv("/content/city_day[1].csv")
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df=data

# %% [markdown]
# # Understanding data

# %% [markdown]
# - City: Name of the city.
# - Date: Date of the observation.
# - PM2.5, PM10, NO, NO2, NOx, NH3, CO, SO2, O3: Various air quality measurements.
# - Benzene, Toluene, Xylene: Concentrations of specific pollutants.
# - AQI: Air Quality Index, a summary indicator of air quality.
# - AQI_Bucket: A categorical label for air quality (e.g., "Good", "Moderate").
#
# **The Air Quality Index (AQI) is a standardized indicator used to communicate how polluted the air currently is or how polluted it is forecasted to become. It simplifies complex air quality data into a single number, color, or descriptive category to help the public understand the potential health implications.**

# %%
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
data.tail()
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %%
data.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
data.shape
# Out:
# (29531, 16)

# %%
print(data.isnull().sum())
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# # Visualization

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'PM2.5'}>,
#         <Axes: title={'center': 'PM10'}>, <Axes: title={'center': 'NO'}>,
#         <Axes: title={'center': 'NO2'}>],
#        [<Axes: title={'center': 'NOx'}>, <Axes: title={'center': 'NH3'}>,
#         <Axes: title={'center': 'CO'}>, <Axes: title={'center': 'SO2'}>],
#        [<Axes: title={'center': 'O3'}>,
#         <Axes: title={'center': 'Benzene'}>,
#         <Axes: title={'center': 'Toluene'}>,
#         <Axes: title={'center': 'Xylene'}>],
#        [<Axes: title={'center': 'AQI'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
for col in data.columns:
    fig, ax = plt.subplots(figsize=(5, 4))
    sns.boxplot(y=data[col], ax=ax)
    plt.title(f"Boxplot of {col}")
    plt.ylabel("Values")
    plt.show()

# %%
for col in data.columns:
    fig, ax = plt.subplots(figsize=(5, 4))
    sns.histplot(y=data[col], ax=ax, kde=True)
    plt.title(f"Boxplot of {col}")
    plt.ylabel("Values")
    plt.show()

# %%
data.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()

data['City'] = le.fit_transform(data['City'])

# %%
# data['City'] = np.log1p(data['City'])
# data['PM2.5'] = np.log1p(data['PM2.5'])
# data['PM10'] = np.log1p(data['PM10'])
# data['NO'] = np.log1p(data['NO'])
# data['NO2'] = np.log1p(data['NO2'])
# data['NOx'] = np.log1p(data['NOx'])
# data['NH3'] = np.log1p(data['NH3'])
# data['CO'] = np.log1p(data['CO'])
# data['SO2'] = np.log1p(data['SO2'])
# data['O3'] = np.log1p(data['O3'])
# data['Benzene'] = np.log1p(data['Benzene'])
# data['Toluene'] = np.log1p(data['Toluene'])

# %%
for col in data.columns:
    fig, ax = plt.subplots(figsize=(5, 4))
    sns.histplot(y=data[col], ax=ax, kde=True)
    plt.title(f"Boxplot of {col}")
    plt.ylabel("Values")
    plt.show()

# %%
data.shape
# Out:
# (29531, 16)

# %%
for col in data.columns:
    fig, ax = plt.subplots(figsize=(5, 4))
    sns.boxplot(y=data[col], ax=ax)
    plt.title(f"Boxplot of {col}")
    plt.ylabel("Values")
    plt.show()

# %% [markdown]
# # Data cleaning

# %%
print(data.isnull().sum())
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  int64
#  1   Date        29531 non-null  datetime64[ns]
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: datetime64[ns](1), float64(13), int64(1), object(1)
# memory usage: 3.6+ MB

# %%
# droping the Xylene column, because this column have more than half of null values
# droping AQI bucket, because this feature used for classisfication so we dropping
data.drop(columns=["Xylene", "AQI_Bucket"], inplace=True)

# %%
data.head()
# Out:
#    City       Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0     0 2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1     0 2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2     0 2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3     0 2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4     0 2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  AQI
# 0  133.36     0.00     0.02  NaN
# 1   34.06     3.68     5.50  NaN
# 2   30.70     6.80    16.40  NaN
# 3   36.08     4.43    10.14  NaN
# 4   39.31     7.01    18.89  NaN

# %%
missing_values=data.isnull().sum()
print(missing_values[missing_values>0])
# Out:
# PM2.5       4598
# PM10       11140
# NO          3582
# NO2         3585
# NOx         4185
# NH3        10328
# CO          2059
# SO2         3854
# O3          4022
# Benzene     5623
# Toluene     8041
# AQI         4681
# dtype: int64

# %%
data.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'AQI'],
#       dtype='object')

# %%
data["PM2.5"].fillna(data["PM2.5"].median(), inplace=True)
data["PM10"].fillna(data["PM10"].median(), inplace=True)
data["NO"].fillna(data["NO"].median(), inplace=True)
data["NO2"].fillna(data["NO2"].median(), inplace=True)
data["NOx"].fillna(data["NOx"].median(), inplace=True)
data["NH3"].fillna(data["NH3"].median(), inplace=True)
data["CO"].fillna(data["CO"].median(), inplace=True)
data["SO2"].fillna(data["SO2"].median(), inplace=True)
data["O3"].fillna(data["O3"].median(), inplace=True)
data["Benzene"].fillna(data["Benzene"].median(), inplace=True)
data["Toluene"].fillna(data["Toluene"].median(), inplace=True)
data["AQI"].fillna(data["AQI"].median(), inplace=True)
# Out:
# <ipython-input-268-a64cd6aefcd2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["PM2.5"].fillna(data["PM2.5"].median(), inplace=True)
# <ipython-input-268-a64cd6aefcd2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.head()
# Out:
#    City       Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0     0 2015-01-01  48.57  95.68   0.92  18.22  17.15  15.85   0.92  27.64
# 1     0 2015-01-02  48.57  95.68   0.97  15.69  16.46  15.85   0.97  24.55
# 2     0 2015-01-03  48.57  95.68  17.40  19.30  29.70  15.85  17.40  29.07
# 3     0 2015-01-04  48.57  95.68   1.70  18.48  17.97  15.85   1.70  18.59
# 4     0 2015-01-05  48.57  95.68  22.10  21.42  37.76  15.85  22.10  39.33
#
#        O3  Benzene  Toluene    AQI
# 0  133.36     0.00     0.02  118.0
# 1   34.06     3.68     5.50  118.0
# 2   30.70     6.80    16.40  118.0
# 3   36.08     4.43    10.14  118.0
# 4   39.31     7.01    18.89  118.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  int64
#  1   Date     29531 non-null  datetime64[ns]
#  2   PM2.5    29531 non-null  float64
#  3   PM10     29531 non-null  float64
#  4   NO       29531 non-null  float64
#  5   NO2      29531 non-null  float64
#  6   NOx      29531 non-null  float64
#  7   NH3      29531 non-null  float64
#  8   CO       29531 non-null  float64
#  9   SO2      29531 non-null  float64
#  10  O3       29531 non-null  float64
#  11  Benzene  29531 non-null  float64
#  12  Toluene  29531 non-null  float64
#  13  AQI      29531 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(1)
# memory usage: 3.2 MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  int64
#  1   Date     29531 non-null  datetime64[ns]
#  2   PM2.5    29531 non-null  float64
#  3   PM10     29531 non-null  float64
#  4   NO       29531 non-null  float64
#  5   NO2      29531 non-null  float64
#  6   NOx      29531 non-null  float64
#  7   NH3      29531 non-null  float64
#  8   CO       29531 non-null  float64
#  9   SO2      29531 non-null  float64
#  10  O3       29531 non-null  float64
#  11  Benzene  29531 non-null  float64
#  12  Toluene  29531 non-null  float64
#  13  AQI      29531 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(1)
# memory usage: 3.2 MB

# %% [markdown]
# # feature engineering

# %%
# Convert the 'date' column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Extract the year
data['Year'] = data['Date'].dt.year

# Extract the month
data['Month'] = data['Date'].dt.month

# Extract the day of the week (0 = Monday, 6 = Sunday)
data['Day_Of_Week'] = data['Date'].dt.dayofweek

# droping previous column
data.drop("Date", axis=1, inplace=True)# Convert the 'date' column to datetime

# %% [markdown]
# # Data Correlation

# %%
cor = data.corr()

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(cor, annot=True, fmt='0.01f', cmap='coolwarm')

plt.show()

# %%
s = data.corr()["AQI"]
s.sort_values(ascending=False)
# Out:
# AQI            1.000000
# CO             0.650475
# PM2.5          0.633654
# NO2            0.531952
# SO2            0.454182
# PM10           0.447686
# NO             0.438039
# NOx            0.436282
# Toluene        0.288749
# O3             0.199100
# NH3            0.097916
# Benzene        0.052027
# Month          0.021516
# Day_Of_Week    0.001385
# City          -0.121778
# Year          -0.129244
# Name: AQI, dtype: float64

# %%
sns.heatmap(s.to_frame(), annot=True, fmt='0.02f', cmap='coolwarm')

plt.show()

# %% [markdown]
# # Outlier detection

# %%
data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # initial modeling

# %%
data
# Out:
#        City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2      O3  \
# 0         0  48.57  95.68   0.92  18.22  17.15  15.85   0.92  27.64  133.36
# 1         0  48.57  95.68   0.97  15.69  16.46  15.85   0.97  24.55   34.06
# 2         0  48.57  95.68  17.40  19.30  29.70  15.85  17.40  29.07   30.70
# 3         0  48.57  95.68   1.70  18.48  17.97  15.85   1.70  18.59   36.08
# 4         0  48.57  95.68  22.10  21.42  37.76  15.85  22.10  39.33   39.31
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 29526    25  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55   23.30
# 29527    25  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72   30.14
# 29528    25  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42   30.96
# 29529    25  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84   28.30
# 29530    25  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10   17.05
#
#        Benzene  Toluene    AQI  Year  Month  Day_Of_Week
# ...

# %%
x = data[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'CO', 'SO2']]
y = data["AQI"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error


mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)


print(f"MSE: {mse}, RMSE: {rmse}, R-squared: {r2}, MAE: {mae}")
# Out:
# MSE: 2997.2813969944646, RMSE: 54.74743278907665, R-squared: 0.8053013310792371, MAE: 30.189890767762904

# %% [markdown]
# # after outlier remove

# %%
df1=data

# %%
df1.drop(columns=['City', 'NO', 'NO2', 'NH3', 'O3',
       'Benzene', 'Toluene', 'Year', 'Month', 'Day_Of_Week'], inplace=True)

# %%
df1
# Out:
#        PM2.5   PM10    NOx     CO    SO2    AQI
# 0      48.57  95.68  17.15   0.92  27.64  118.0
# 1      48.57  95.68  16.46   0.97  24.55  118.0
# 2      48.57  95.68  29.70  17.40  29.07  118.0
# 3      48.57  95.68  17.97   1.70  18.59  118.0
# 4      48.57  95.68  37.76  22.10  39.33  118.0
# ...      ...    ...    ...    ...    ...    ...
# 29526  15.02  50.94  19.54   0.47   8.55   41.0
# 29527  24.38  74.09  16.53   0.52  12.72   70.0
# 29528  22.91  65.73  18.33   0.48   8.42   68.0
# 29529  16.64  49.97  18.80   0.52   9.84   54.0
# 29530  15.00  66.00  14.05   0.59   2.10   50.0
#
# [29531 rows x 6 columns]

# %%
df1['AQI'] = np.log1p(df1['AQI'])

# %%
def remove_outliers_iqr(df1, exclud_column):
    for col in df1.columns:
      if col == exclud_column:
          continue
      Q1 = df1[col].quantile(0.25)
      Q3 = df1[col].quantile(0.75)
      IQR = Q3 - Q1
      lower_bound = Q1 - 1.5 * IQR
      upper_bound = Q3 + 1.5 * IQR
      # Filter the DataFrame to remove rows with outliers in each column
      df1 = df1[(df1[col] >= lower_bound) & (df1[col] <= upper_bound)]
    return df1

# Specify the column to exclude
df1_cleaned = remove_outliers_iqr(df1, exclud_column="AQI")
df1_cleaned
# Out:
#        PM2.5   PM10    NOx    CO    SO2       AQI
# 9      48.57  95.68   0.00  0.89   8.29  0.699699
# 56     48.57  95.68  23.52  0.89   9.16  0.699699
# 57     48.57  95.68  23.52  0.89   9.16  0.699699
# 58     48.57  95.68  23.52  0.89   9.16  0.699699
# 64     48.57  95.68  23.52  0.89   9.16  0.699699
# ...      ...    ...    ...   ...    ...       ...
# 29526  15.02  50.94  19.54  0.47   8.55  0.661794
# 29527  24.38  74.09  16.53  0.52  12.72  0.682373
# 29528  22.91  65.73  18.33  0.48   8.42  0.681337
# 29529  16.64  49.97  18.80  0.52   9.84  0.672790
# 29530  15.00  66.00  14.05  0.59   2.10  0.669807
#
# [17736 rows x 6 columns]

# %%
x = df1_cleaned[['PM2.5', "PM10", 'NOx', 'CO', 'SO2']]
y = df1_cleaned["AQI"]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error


mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)


print(f"MSE: {mse}, RMSE: {rmse}, R-squared: {r2}, MAE: {mae}")
# Out:
# MSE: 6.428939616059683e-05, RMSE: 0.008018066859324437, R-squared: 0.6403571241921424, MAE: 0.005874791595744754

# %% [markdown]
# # after AQI skewness remove

# %%
df['AQI'] = np.log1p(df['AQI'])

# %%
sns.histplot(df["AQI"], kde=True)
plt.show()

# %%
sns.boxplot(df["AQI"])
plt.show()

# %%
x = df[['PM2.5', "PM10", 'NOx', 'CO', 'SO2']]
y = df["AQI"]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error


mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)


print(f"MSE: {mse}, RMSE: {rmse}, R-squared: {r2}, MAE: {mae}")
# Out:
# MSE: 0.0004769217803941702, RMSE: 0.021838538879562667, R-squared: 0.6448414520309176, MAE: 0.01580334316097117
